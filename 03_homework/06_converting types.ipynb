# %% [markdown]
# # Converting Types
# ## Practice Problems

# %% [markdown]
# ### 1. Convert the following to strings

# %%
13
87
6 * 10

# %% [markdown]
# `9 / 2`

# %%
# Task: Convert the following to strings

# Integer 13
num1 = "13"
print(num1)

# Integer 87
num2 = "87"
print(num2)

# Expression 6 * 10 as string
expression1 = "6 * 10"
print(expression1)

# Expression 9 / 2 as string
expression2 = "9 / 2"
print(expression2)
# Out:
# 13
# 87
# 6 * 10
# 9 / 2

# %% [markdown]
# `9 // -2`

# %%
# Task: Convert the following to strings
# Expression 9 // -2 as string
expression3 = "9 // -2"
print(expression3_str)
# Out:
# 9 // -2

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
# Task: Convert the following to strings
# Expression 1.5 * 2 >= 7 - 3 as string
expression4 = "1.5 * 2 >= 7 - 3"
print(expression4)
# Out:
# 1.5 * 2 >= 7 - 3

# %% [markdown]
# ### 2. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `*` > `+`
# </details>
#
#
# `5 - 2 * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `**` > `*` > `-`
# </details>
#
# `(5 - 2) * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `(-)` > `**` > `*`
# </details>
#
# `5 + 2 >= 3 * 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `+` > `>=`
# </details>
