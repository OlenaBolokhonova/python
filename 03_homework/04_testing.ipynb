# %% [markdown]
# # Functions
# ## Practice Problems

# %% [markdown]
# Using assignment 1, write assertion tests on each part!

# %%
# Function definition
def anagram_checker(word_a, word_b):
    # Convert both words to lowercase using str.lower()
    word_a = word_a.lower()
    word_b = word_b.lower()

    # Sort the characters in both words
    sorted_word_a = sorted(word_a)
    sorted_word_b = sorted(word_b)

    # Compare the sorted lists to determine if they are anagrams
    return sorted_word_a == sorted_word_b

# Testing the function with assertions
def test_anagram_checker():
    assert anagram_checker("Slient", "listen") == True

# Run the tests
test_anagram_checker()

print("All test cases passed successfully!")
# Out:
# All test cases passed successfully!

# %%
# Function definition
def anagram_checker(word_a, word_b):
    # Convert both words to lowercase using str.lower()
    word_a = word_a.lower()
    word_b = word_b.lower()

    # Sort the characters in both words
    sorted_word_a = sorted(word_a)
    sorted_word_b = sorted(word_b)

    # Compare the sorted lists to determine if they are anagrams
    return sorted_word_a == sorted_word_b

# Testing the function with assertions
def test_anagram_checker():
    assert anagram_checker("Slient", "Night") == False

# Run the tests
test_anagram_checker()

print("All test cases passed successfully!")
# Out:
# All test cases passed successfully!

# %%
# Function definition
def anagram_checker(word_a, word_b):
    # Convert both words to lowercase using str.lower()
    word_a = word_a.lower()
    word_b = word_b.lower()

    # Sort the characters in both words
    sorted_word_a = sorted(word_a)
    sorted_word_b = sorted(word_b)

    # Compare the sorted lists to determine if they are anagrams
    return sorted_word_a == sorted_word_b

# Testing the function with assertions
def test_anagram_checker():
    assert anagram_checker("night", "Thing") == True

# Run the tests
test_anagram_checker()

print("All test cases passed successfully!")
# Out:
# All test cases passed successfully!
