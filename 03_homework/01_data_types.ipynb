# %% [markdown]
# # Getting Started: Python Fundamentals
# ## Practice Problems

# %% [markdown]
# ### 1. What types are involved in the following expressions? What data type will each expression evaluate to?
#
# `8 * 2.5`

# %%
# Your code here Types involved: int (8) and float (2.5)
# Data type of the result: When an integer is multiplied by a float, the result is a float.

# %% [markdown]
# `9 / 2`

# %%
# Your code here Types involved: int (9) and int (2) 
# Data type of the result: the division operator (/) returns a float

# %% [markdown]
# `9 // -2`

# %%
# Your code here Types involved: int (9) and int (-2)
# Data type of the result: The floor division operator (//) returns the largest possible integer that is less than or equal to the division result. 
# Since both operands are integers, the result will also be an int.

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
# Your code here 
# Types involved:
# Left side of >=: float (1.5) multiplied by int (2), resulting in float (3.0)
# Right side of >=: int (7) minus int (3), resulting in int (4)
# Data type of the result: 
#The comparison operator (>=) compares the two numbers and returns a boolean value

# %% [markdown]
# ### 2. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `*` > `+`
# </details>
#
#
# `5 - 2 * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `**` > `*` > `-`
# </details>
#
# `(5 - 2) * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `(-)` > `**` > `*`
# </details>
#
# `5 + 2 >= 3 * 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `+` > `>=`
# </details>
